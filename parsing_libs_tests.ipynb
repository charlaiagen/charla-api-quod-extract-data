# %% [markdown]
# ## PyPDF

# %% [markdown]
# ### Atradius

# %%
from pypdf import PdfReader

reader = PdfReader("data/atradius.pdf")
number_of_pages = len(reader.pages)
page = reader.pages[0]
text = page.extract_text()
print(text)
# Out:
# Atradius Crédito y Caución Seguradora S.A.
# CNPJ nº 08.587.950/0001-76
# Conjuntura:
# O exercício 2023 mostrou-se fortemente desaﬁ  ador às seguradoras de crédito como antecipamos em
# 2022 no item Perspectivas  ao ﬁ  nal do Relatório da Administração  que acompanhou a divulgação de nos-
# sas Demonstrações Financeiras  à época. No mercado doméstico, a recuperação judicial do Grupo Ame-
# ricanas decretada logo no início do ano representou um choque de proporções materiais à grande maio-
# ria das seguradoras em operação no país, impactando fortemente a sinistralidade. Este advento ampli-
# ﬁ  cou tendência já identiﬁ  cada de deterioração dos fundamentos do crédito corporativo ante a juros reais
# altos mantidos por bastante tempo pelo Copom, assim desaﬁ  ando a capacidade das empresas a servi-
# rem suas dívidas. Neste contexto, o advento Americanas atuou como um choque não antecipado que
# ...

# %% [markdown]
# ### Esferatur

# %%
reader = PdfReader("data/esferatur.pdf")
page = reader.pages[0]
text = page.extract_text()
print(text)
# Out:
# Balanço patrimonial - Exercício findo em 31 de dezembro de 2022 e 2021 (Em milhares de Reais)
# Ativo 31/12/2022 31/12/2021
# Circulante
# Caixa e equivalentes de caixa 19.409 6.126
# Contas a receber de clientes 8.148 22.043
# Adiantamento a fornecedores - 2
# Contas a receber - partes relacionadas 610 1.046
# Impostos a recuperar 1.227 948
# Outras contas a receber 4.510 4.625
# Total do ativo circulante 33.904 34.790
# Não circulante
# Impostos diferidos 11.905 13.737
# Depósito judiciais 20 84
# Impostos a recuperar 1.233 -
# Ativo imobilizado 263 455
# Ativo intangível 305 447
# Ativos de direito de uso - 175
# Total do ativo não circulante 13.726 14.898
# Total do ativo 47.630 49.688
# Passivo e patrimônio líquido 31/12/2022 31/12/2021
# Circulante
# Fornecedores 6.865 6.706
# Contas a pagar - partes relacionadas 27.788 10.561
# Salários e encargos sociais      2.197 3.421
# Impostos e contribuições a pagar 265 625
# Passivos de arrendamento - 191
# ...

# %% [markdown]
# ### Monark

# %%
reader = PdfReader("data/monark.pdf")
page = reader.pages[0]
text = page.extract_text()
print(text)
# Out:
# BICICLETAS MONARK S.A.
# CNPJ nº 56.992.423/0001-90
# NOTAS EXPLICATIVAS ÀS DEMONSTRAÇÕES FINANCEIRAS
# 1. CONTEXTO OPERACIONAL: A Bicicletas Monark S.A. (“Companhia”) tem por
# objetivo a industrialização e comercialização de bicicletas, assim como a participação
# em outras sociedades. 2. BASES DE APRESENTAÇÃO E ELABORAÇÃO DAS IN-
# FORMAÇÕES DAS DEMONSTRAÇÕES FINANCEIRAS: As demonstrações finan-
# ceiras foram elaboradas e estão apresentadas em conformidade com as práticas
# contábeis adotadas no Brasil e os pronunciamentos, orientações e interpretações
# técnicas emitidas pelo Comitê de Pronunciamentos Contábeis - CPC aprovados pela
# Comissão de Valores Mobiliários. A Administração declara que todas as informações
# relevantes próprias das demonstrações financeiras, e somente elas, estão sendo evi-
# denciadas e correspondem as utilizadas pela Administração na sua gestão. As de-
# monstrações financeiras são apresentadas em Reais (R$), que é a moeda funcional
# ...

# %% [markdown]
# ### Rominor

# %%
reader = PdfReader("data/rominor.pdf")
page = reader.pages[0]
text = page.extract_text()
print(text)
# Out:
# Notas explicativas da administração às demonstrações
# financeiras em 31 de dezembro de 2022
#  Em reais, exceto quando indicado de outra forma
# 1. Contexto operacional: A Rominor Empreendimentos Imobiliários S.A.
# (“Companhia”) tem por objetivo a participação em empreendimentos imo-
# biliários, incluindo incorporação, promoção, administração, planejamento,
# desenvolvimento, implantação, comercialização e intermediação; a co-
# mercialização de bens imóveis, inclusive a compra e venda; a exploração
# de direitos imobiliários, inclusive aquisição, alienação e locação; a presta-
# ção de serviços de administração de bens imóveis, e de consultoria sobre
# assuntos imobiliários; a construção civil, a execução de obras e a presta-
# ção de serviços de engenharia e correlatos no ramo imobiliário e a parti-
# cipação societária em outras sociedades e associações. 2. Resumo das
# principais práticas contábeis: As principais políticas contábeis aplica-
# ...

# %% [markdown]
# ### SBIC

# %%
reader = PdfReader("data/SBIC.pdf")
page = reader.pages[0]
text = page.extract_text()
print(text)
# Out:
# terça-feira, 13 de março de 2012 Diário Oﬁ cial Empresarial São Paulo, 122 (48) – 55
# Balanço Patrimonial em 31 de Dezembro (Em reais)
# Demonstrações Financeiras em 31 de Dezembro de 2011 e 2010
# Notas Explicativas às Demonstrações Financeiras em
# 31 de Dezembro de 2011 e 2010 (Em reais)
# a receber e outros recebíveis, incluindo a recebíveis relativos a caixa
# e equivalentes de caixa, assim como contas a pagar e outras dívidas.
# Instrumentos ﬁ  nanceiros não-derivativos são reconhecidos inicialmente
# pelo valor justo acrescido de quaisquer custos de transação diretamente
# atribuíveis. e) Ativos circulantes e não circulantes - As contas a receber
# são registradas pelos valores negociados, ajustado ao valor presente
# quando aplicável. O cálculo do valor presente, quando aplicável, é efetuado
# para cada transação com base numa taxa de juros que reﬂ  ete o prazo, a
# moeda e o risco de cada transação. A contrapartida dos ajustes a valor
# ...

# %% [markdown]
# ### Vamos

# %%
reader = PdfReader("data/vamos.pdf")
page = reader.pages[2]
text = page.extract_text()
print(text)
# Out:
# BALANÇO PATRIMONIAL
# Em 31 de dezembro de 2021 e 2020 - Em milhares de reais
#                                       ATIVO Controladora Consolidado_____________________________________________  _____________________ _____________________
# Circulante Notas 31/12/2021 31/12/2020 31/12/2021 31/12/2020    ______ _________ _________ _________ _________
# Caixa e equivalentes de caixa  7 121.702 13.206 153.161 18.405
# Títulos, valores mobiliários e aplicações financeiras 8 3.587.754 627.565 3.671.780 760.905
# Contas a receber 9 238.402 159.624 526.487 267.478
# Estoques  10 1.564 1.313 332.518 88.963
# Tributos a recuperar   1.723 1.288 31.143 17.439
# Imposto de renda e contribuição social a recuperar 23.4 60.684 27.103 67.997 31.836
# Ativo imobilizado disponibilizado para venda 11 39.335 33.003 42.016 38.005
# Despesas antecipadas   9.891 24.323 15.072 27.536
# Adiantamentos a terceiros   7.709 2.026 21.257 14.039
# Dividendos a receber  13.3 107.070 2.322 - -
# ...

# %% [markdown]
# ### Wibson

# %%
reader = PdfReader("data/Wibson_-_Balanco_2023.pdf")
text = ""
for page in reader.pages:
    text += page.extract_text()

print(text)
# Out:
# Balanço Patrimonial
# Empresa: WIBSON DESENVOLVIMENTO DE SOFTWARE LTDA.
# CNPJ: 45188606000130
# Período: 01/2023 - 12/2023
# Descrição 2023 2022
# ATIVO 87.572,55D 40.775,72D
# CIRCULANTE 13.806,13D 5.827,95D
# CAIXA E EQUIVALENTES DE CAIXA 10.614,32D 5.827,95D
# CAIXA 0,00C 0,00D
# Caixa Geral 0,00C 0,00D
# BANCOS 10.614,32D 5.827,95D
# Banco BS2 S.A. 10.614,32D 5.827,95D
# CRÉDITOS 3.191,81D 0,00D
# CLIENTES A RECEBER 3.191,81D 0,00D
# Clientes Diversos 3.191,81D 0,00D
# IMPOSTOS A RECUPERAR 0,00C 0,00D
# IRPJ a Recuperar 0,00C 0,00D
# CSLL a Recuperar 0,00C 0,00D
# PIS a Recuperar - Crédito Básico 0,00C 0,00D
# COFINS a Recuperar - Crédito Básico 0,00C 0,00D
# ATIVO NÃO CIRCULANTE 73.766,42D 34.947,77D
# REALIZÁVEL A LONGO PRAZO 73.766,42D 34.947,77D
# CRÉDITOS COM PESSOAS LIGADAS 73.766,42D 34.947,77D
# Créditos com Pessoas Ligadas - FISICAS 73.766,42D 34.947,77D
# PASSIVO 87.572,55C 40.775,72C
# CIRCULANTE 11.620,59C 9.210,44C
# OBRIGAÇÕES DE CURTO PRAZO 11.620,59C 9.210,44C
# ...

# %%
import pandas as pd

# Dados fornecidos
dados = {
    "Ativo Circulante": [
        {"Conta": "Caixa e equivalentes de caixa", "2023": 10614.32, "2022": 5827.95},
        {"Conta": "Caixa", "2023": 0.00, "2022": 0.00},
        {"Conta": "Caixa Geral", "2023": 0.00, "2022": 0.00},
        {"Conta": "Bancos", "2023": 10614.32, "2022": 5827.95},
        {"Conta": "Banco BS2 S.A.", "2023": 10614.32, "2022": 5827.95},
        {"Conta": "Créditos", "2023": 3191.81, "2022": 0.00},
        {"Conta": "Clientes a receber", "2023": 3191.81, "2022": 0.00},
        {"Conta": "Clientes Diversos", "2023": 3191.81, "2022": 0.00},
        {"Conta": "Impostos a recuperar", "2023": 0.00, "2022": 0.00},
        {"Conta": "IRPJ a Recuperar", "2023": 0.00, "2022": 0.00},
        {"Conta": "CSLL a Recuperar", "2023": 0.00, "2022": 0.00},
        {"Conta": "PIS a Recuperar - Crédito Básico", "2023": 0.00, "2022": 0.00},
        {"Conta": "COFINS a Recuperar - Crédito Básico", "2023": 0.00, "2022": 0.00},
        {"Conta": "Total do ativo circulante", "2023": 13806.13, "2022": 5827.95},
    ],
    "Ativo Não Circulante": [
        {"Conta": "Realizável a longo prazo", "2023": 73766.42, "2022": 34947.77},
        {"Conta": "Créditos com pessoas ligadas", "2023": 73766.42, "2022": 34947.77},
        {"Conta": "Créditos com pessoas ligadas - Físicas", "2023": 73766.42, "2022": 34947.77},
        {"Conta": "Total do ativo não circulante", "2023": 73766.42, "2022": 34947.77},
    ],
    "Passivo Circulante": [
        {"Conta": "Obrigações de curto prazo", "2023": 11620.59, "2022": 9210.44},
        {"Conta": "Fornecedores", "2023": 2674.00, "2022": 7965.13},
        {"Conta": "Adiantamentos de clientes", "2023": 0.00, "2022": 7965.13},
        {"Conta": "Honorários a pagar", "2023": 2674.00, "2022": 0.00},
        {"Conta": "Impostos a recolher", "2023": 684.57, "2022": 214.57},
        {"Conta": "Tributos municipais a recolher - ISS", "2023": 684.57, "2022": 214.57},
        {"Conta": "Contribuições a recolher", "2023": 35.26, "2022": 25.65},
        {"Conta": "PIS a recolher", "2023": 10.00, "2022": 7.74},
        {"Conta": "COFINS a recolher", "2023": 25.26, "2022": 17.91},
        {"Conta": "Contribuições tributárias diversas", "2023": 0.00, "2022": 0.00},
        {"Conta": "Outros tributos a recolher", "2023": 0.00, "2022": 0.00},
        {"Conta": "Provisão para CSLL", "2023": 1329.28, "2022": 371.03},
        {"Conta": "Provisão para IRPJ", "2023": 6897.48, "2022": 634.06},
        {"Conta": "Total do passivo circulante", "2023": 11620.59, "2022": 9210.44},
    ],
    "Patrimônio Líquido": [
        {"Conta": "Capital social", "2023": 50000.00, "2022": 50000.00},
        {"Conta": "Capital realizado", "2023": 50000.00, "2022": 50000.00},
        {"Conta": "Lucros e prejuízos acumulados", "2023": 25951.96, "2022": -18434.72},
        {"Conta": "Lucros acumulados", "2023": 25951.96, "2022": 0.00},
        {"Conta": "(-) Prejuízos acumulados", "2023": 0.00, "2022": -18434.72},
        {"Conta": "Total do patrimônio líquido", "2023": 75951.96, "2022": 31565.28},
    ],
}

# Construção dos DataFrames
ativos_circulantes_df = pd.DataFrame(dados["Ativo Circulante"])
ativos_nao_circulantes_df = pd.DataFrame(dados["Ativo Não Circulante"])
passivos_circulantes_df = pd.DataFrame(dados["Passivo Circulante"])
patrimonio_liquido_df = pd.DataFrame(dados["Patrimônio Líquido"])

# Exibição dos DataFrames
print("Ativo Circulante:")
print(ativos_circulantes_df)
print("\nAtivo Não Circulante:")
print(ativos_nao_circulantes_df)
print("\nPassivo Circulante:")
print(passivos_circulantes_df)
print("\nPatrimônio Líquido:")
print(patrimonio_liquido_df)
# Out:
# Ativo Circulante:
#                                   Conta      2023     2022
# 0         Caixa e equivalentes de caixa  10614.32  5827.95
# 1                                 Caixa      0.00     0.00
# 2                           Caixa Geral      0.00     0.00
# 3                                Bancos  10614.32  5827.95
# 4                        Banco BS2 S.A.  10614.32  5827.95
# 5                              Créditos   3191.81     0.00
# 6                    Clientes a receber   3191.81     0.00
# 7                     Clientes Diversos   3191.81     0.00
# 8                  Impostos a recuperar      0.00     0.00
# 9                      IRPJ a Recuperar      0.00     0.00
# 10                     CSLL a Recuperar      0.00     0.00
# 11     PIS a Recuperar - Crédito Básico      0.00     0.00
# 12  COFINS a Recuperar - Crédito Básico      0.00     0.00
# 13            Total do ativo circulante  13806.13  5827.95
#
# Ativo Não Circulante:
# ...

# %%
import pandas as pd

# Dados fornecidos
empresa = 'Atradius Crédito y Caución Seguradora S.A.'
unidade_monetaria = 'Milhares de R$'
datas = ['31.12.2023', '31.12.2022']

# Dados organizados em dicionários
dados = {
    "Ativo Circulante": [
        "Disponível - caixa e bancos",
        "Equivalentes de caixa",
        "Aplicações",
        "Créditos das operações com seguros e resseguros",
        "Prêmios a receber",
        "Operações com resseguradoras",
        "Ativos de resseguro e retrocessão",
        "Outros valores e bens",
        "Títulos e créditos a receber",
        "Créditos tributários e previdenciários",
        "Outros créditos",
        "Despesas antecipadas",
        "Custos de aquisição diferidos - seguros",
        "Total do ativo circulante"
    ],
    "Ativo Não Circulante": [
        "Realizável a longo prazo",
        "Aplicações",
        "Créditos das operações com seguros e resseguros",
        "Prêmios a receber",
        "Ativos de resseguro e retrocessão",
        "Outros valores e bens",
        "Empréstimos e depósitos compulsórios",
        "Custos de aquisição diferidos - seguros",
        "Imobilizado - bens móveis",
        "Intangível",
        "Total do ativo não circulante"
    ],
    "Passivo Circulante": [
        "Contas a pagar",
        "Obrigações a pagar",
        "Impostos e encargos sociais a recolher",
        "Encargos trabalhistas",
        "Impostos e contribuições",
        "Outras contas a pagar",
        "Débitos das operações com seguros e resseguros",
        "Operações com resseguradoras",
        "Corretores de seguros e resseguros",
        "Depósito de terceiros",
        "Provisões técnicas – seguros danos",
        "Débitos diversos",
        "Total do passivo circulante"
    ],
    "Passivo Não Circulante": [
        "Débitos das operações com seguros e resseguros",
        "Operações com resseguradoras",
        "Corretores de seguros e resseguros",
        "Provisões técnicas – seguros danos",
        "Outros débitos",
        "Total do passivo não circulante"
    ],
    "Patrimônio Líquido": [
        "Capital social",
        "Reservas de lucros",
        "Total do patrimônio líquido"
    ],
    "Demonstração do Resultado": [
        "Prêmios emitidos",
        "Variações das provisões técnicas de prêmios",
        "Prêmios ganhos",
        "Sinistros ocorridos",
        "Custos de aquisição",
        "Outras receitas e despesas operacionais",
        "Resultado com resseguro",
        "Receitas com resseguro",
        "Despesas com resseguro",
        "Despesas administrativas",
        "Despesas com tributos",
        "Resultado financeiro",
        "Resultado operacional",
        "Ganhos ou perdas com ativos não correntes",
        "Resultado antes dos impostos e participações",
        "Imposto de renda",
        "Contribuição social",
        "Participações sobre o resultado",
        "Lucro líquido do exercício",
        "Quantidade de ações (em milhares)",
        "Lucro líquido por ação – em R$"
    ]
}

valores = {
    "Ativo Circulante": [
        ["1", "2"],
        ["23.092", "27.491"],
        ["74.119", "60.989"],
        ["135.726", "131.816"],
        ["129.402", "121.512"],
        ["6.324", "10.304"],
        ["126.250", "109.148"],
        ["533", "643"],
        ["801", "709"],
        ["801", "705"],
        ["-", "4"],
        ["169", "33"],
        ["12.749", "13.374"],
        ["373.440", "344.205"]
    ],
    "Ativo Não Circulante": [
        ["43.113", "34.677"],
        ["6.159", "-"],
        ["11.473", "10.967"],
        ["11.473", "10.967"],
        ["22.554", "19.909"],
        ["31", "-"],
        ["35", "35"],
        ["2.861", "3.766"],
        ["452", "615"],
        ["85", "111"],
        ["43.650", "35.403"]
    ],
    "Passivo Circulante": [
        ["8.003", "7.661"],
        ["1.838", "1.524"],
        ["4.793", "5.021"],
        ["1.113", "922"],
        ["199", "128"],
        ["60", "66"],
        ["116.370", "117.545"],
        ["103.350", "102.593"],
        ["13.020", "14.952"],
        ["4", "-"],
        ["169.305", "144.812"],
        ["529", "632"],
        ["294.211", "270.650"]
    ],
    "Passivo Não Circulante": [
        ["7.715", "8.478"],
        ["7.042", "6.952"],
        ["673", "1.526"],
        ["34.736", "29.110"],
        ["34", "-"],
        ["42.485", "37.588"]
    ],
    "Patrimônio Líquido": [
        ["40.489", "40.489"],
        ["39.905", "30.881"],
        ["80.394", "71.370"]
    ],
    "Demonstração do Resultado": [
        ["140.698", "166.340"],
        ["(19.751)", "(28.976)"],
        ["120.947", "137.364"],
        ["(348.885)", "(34.493)"],
        ["(13.751)", "(16.287)"],
        ["(571)", "(329)"],
        ["266.280", "(57.150)"],
        ["352.434", "37.675"],
        ["(86.154)", "(94.825)"],
        ["(17.991)", "(14.759)"],
        ["(3.025)", "(3.456)"],
        ["12.597", "7.117"],
        ["15.601", "18.007"],
        ["55", "29"],
        ["15.656", "18.036"],
        ["(4.018)", "(4.493)"],
        ["(2.367)", "(2.511)"],
        ["(247)", "(216)"],
        ["9.024", "10.816"],
        ["42.658", "42.658"],
        ["0,2115", "0,2535"]
    ]
}

# Função para criar DataFrame a partir dos dados
def criar_dataframe(categoria, valores, datas):
    df = pd.DataFrame(valores, columns=datas)
    df.insert(0, "Categoria", categoria)
    return df

# Criando DataFrames para cada seção
df_ativo_circulante = criar_dataframe(dados["Ativo Circulante"], valores["Ativo Circulante"], datas)
df_ativo_nao_circulante = criar_dataframe(dados["Ativo Não Circulante"], valores["Ativo Não Circulante"], datas)
df_passivo_circulante = criar_dataframe(dados["Passivo Circulante"], valores["Passivo Circulante"], datas)
df_passivo_nao_circulante = criar_dataframe(dados["Passivo Não Circulante"], valores["Passivo Não Circulante"], datas)
df_patrimonio_liquido = criar_dataframe(dados["Patrimônio Líquido"], valores["Patrimônio Líquido"], datas)
df_demonstracao_resultado = criar_dataframe(dados["Demonstração do Resultado"], valores["Demonstração do Resultado"], datas)

# Exibindo os DataFrames
print("Ativo Circulante:")
print(df_ativo_circulante)
print("\nAtivo Não Circulante:")
print(df_ativo_nao_circulante)
print("\nPassivo Circulante:")
print(df_passivo_circulante)
print("\nPassivo Não Circulante:")
print(df_passivo_nao_circulante)
print("\nPatrimônio Líquido:")
print(df_patrimonio_liquido)
print("\nDemonstração do Resultado:")
print(df_demonstracao_resultado)
# Out:
# Ativo Circulante:
#                                           Categoria 31.12.2023 31.12.2022
# 0                       Disponível - caixa e bancos          1          2
# 1                             Equivalentes de caixa     23.092     27.491
# 2                                        Aplicações     74.119     60.989
# 3   Créditos das operações com seguros e resseguros    135.726    131.816
# 4                                 Prêmios a receber    129.402    121.512
# 5                      Operações com resseguradoras      6.324     10.304
# 6                 Ativos de resseguro e retrocessão    126.250    109.148
# 7                             Outros valores e bens        533        643
# 8                      Títulos e créditos a receber        801        709
# 9            Créditos tributários e previdenciários        801        705
# 10                                  Outros créditos          -          4
# ...

# %%
# Importação das bibliotecas necessárias
import pandas as pd

# Declaração das variáveis com os dados fornecidos
empresa = 'Atradius Crédito y Caución Seguradora S.A.'
unidade_monetaria = 'Milhares de R$'
datas = ['31.12.2023', '31.12.2022']

ativo_circulante = [
    'Disponível - caixa e bancos: 1, 2',
    'Equivalentes de caixa: 23.092, 27.491',
    'Aplicações: 74.119, 60.989',
    'Créditos das operações com seguros e resseguros: 135.726, 131.816',
    'Prêmios a receber: 129.402, 121.512',
    'Operações com resseguradoras: 6.324, 10.304',
    'Ativos de resseguro e retrocessão: 126.250, 109.148',
    'Outros valores e bens: 533, 643',
    'Títulos e créditos a receber: 801, 709',
    'Créditos tributários e previdenciários: 801, 705',
    'Outros créditos: -, 4',
    'Despesas antecipadas: 169, 33',
    'Custos de aquisição diferidos - seguros: 12.749, 13.374',
    'Total do ativo circulante: 373.440, 344.205'
]

ativo_nao_circulante = [
    'Realizável a longo prazo: 43.113, 34.677',
    'Aplicações: 6.159, -',
    'Créditos das operações com seguros e resseguros: 11.473, 10.967',
    'Prêmios a receber: 11.473, 10.967',
    'Ativos de resseguro e retrocessão: 22.554, 19.909',
    'Outros valores e bens: 31, -',
    'Empréstimos e depósitos compulsórios: 35, 35',
    'Custos de aquisição diferidos - seguros: 2.861, 3.766',
    'Imobilizado - bens móveis: 452, 615',
    'Intangível: 85, 111',
    'Total do ativo não circulante: 43.650, 35.403'
]

passivo_circulante = [
    'Contas a pagar: 8.003, 7.661',
    'Obrigações a pagar: 1.838, 1.524',
    'Impostos e encargos sociais a recolher: 4.793, 5.021',
    'Encargos trabalhistas: 1.113, 922',
    'Impostos e contribuições: 199, 128',
    'Outras contas a pagar: 60, 66',
    'Débitos das operações com seguros e resseguros: 116.370, 117.545',
    'Operações com resseguradoras: 103.350, 102.593',
    'Corretores de seguros e resseguros: 13.020, 14.952',
    'Depósito de terceiros: 4, -',
    'Provisões técnicas – seguros danos: 169.305, 144.812',
    'Débitos diversos: 529, 632',
    'Total do passivo circulante: 294.211, 270.650'
]

passivo_nao_circulante = [
    'Débitos das operações com seguros e resseguros: 7.715, 8.478',
    'Operações com resseguradoras: 7.042, 6.952',
    'Corretores de seguros e resseguros: 673, 1.526',
    'Provisões técnicas – seguros danos: 34.736, 29.110',
    'Outros débitos: 34, -',
    'Total do passivo não circulante: 42.485, 37.588'
]

patrimonio_liquido = [
    'Capital social: 40.489, 40.489',
    'Reservas de lucros: 39.905, 30.881',
    'Total do patrimônio líquido: 80.394, 71.370'
]

demonstracao_do_resultado = [
    'Prêmios emitidos: 140.698, 166.340',
    'Variações das provisões técnicas de prêmios: (19.751), (28.976)',
    'Prêmios ganhos: 120.947, 137.364',
    'Sinistros ocorridos: (348.885), (34.493)',
    'Custos de aquisição: (13.751), (16.287)',
    'Outras receitas e despesas operacionais: (571), (329)',
    'Resultado com resseguro: 266.280, (57.150)',
    'Receitas com resseguro: 352.434, 37.675',
    'Despesas com resseguro: (86.154), (94.825)',
    'Despesas administrativas: (17.991), (14.759)',
    'Despesas com tributos: (3.025), (3.456)',
    'Resultado financeiro: 12.597, 7.117',
    'Resultado operacional: 15.601, 18.007',
    'Ganhos ou perdas com ativos não correntes: 55, 29',
    'Resultado antes dos impostos e participações: 15.656, 18.036',
    'Imposto de renda: (4.018), (4.493)',
    'Contribuição social: (2.367), (2.511)',
    'Participações sobre o resultado: (247), (216)',
    'Lucro líquido do exercício: 9.024, 10.816',
    'Quantidade de ações (em milhares): 42.658, 42.658',
    'Lucro líquido por ação – em R$: 0,2115, 0,2535'
]

# Função para construir o DataFrame
def construir_dataframe():
    # Combina todas as categorias de dados em uma única lista
    categorias = [
        ('Ativo Circulante', ativo_circulante),
        ('Ativo Não Circulante', ativo_nao_circulante),
        ('Passivo Circulante', passivo_circulante),
        ('Passivo Não Circulante', passivo_nao_circulante),
        ('Patrimônio Líquido', patrimonio_liquido),
        ('Demonstração do Resultado', demonstracao_do_resultado)
    ]

    # Lista para armazenar os dados processados
    dados = []

    # Processa cada categoria
    for categoria, itens in categorias:
        for item in itens:
            # Divide o texto em nome e valores
            nome, valores = item.split(': ')
            valor_2023, valor_2022 = valores.split(', ')

            # Adiciona os dados processados à lista
            dados.append({
                'Categoria': categoria,
                'Conta': nome.strip(),
                '31.12.2023': valor_2023.strip(),
                '31.12.2022': valor_2022.strip()
            })

    # Cria o DataFrame a partir dos dados processados
    df = pd.DataFrame(dados)
    return df

# Chamada da função para construir o DataFrame
df_resultado = construir_dataframe()

# Exibe o DataFrame resultante
print(df_resultado)
# Out:
#                     Categoria  \
# 0            Ativo Circulante
# 1            Ativo Circulante
# 2            Ativo Circulante
# 3            Ativo Circulante
# 4            Ativo Circulante
# ..                        ...
# 63  Demonstração do Resultado
# 64  Demonstração do Resultado
# 65  Demonstração do Resultado
# 66  Demonstração do Resultado
# 67  Demonstração do Resultado
#
#                                               Conta 31.12.2023 31.12.2022
# 0                       Disponível - caixa e bancos          1          2
# 1                             Equivalentes de caixa     23.092     27.491
# 2                                        Aplicações     74.119     60.989
# 3   Créditos das operações com seguros e resseguros    135.726    131.816
# 4                                 Prêmios a receber    129.402    121.512
# ..                                              ...        ...        ...
# 63                              Contribuição social    (2.367)    (2.511)
# ...
